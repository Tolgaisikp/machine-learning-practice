# %% [markdown]
# # 1. Import Dependencies

# %%
import gym
import gym_anytrading
from gym_anytrading.envs import ForexEnv
from gym_anytrading.datasets import FOREX_EURUSD_1H_ASK

from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import A2C

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

import os

# %% [markdown]
# # 2. Bring in Marketwatch GME Data

# %%
df = pd.read_csv('data/Download Data - STOCK_US_XNYS_GME.csv')
df.head()
# Out:
#          Date    Open    High     Low   Close     Volume
# 0  11/11/2021  200.00  208.09  198.15  204.32  1,079,401
# 1  11/10/2021  202.12  207.39  196.50  199.19  1,309,389
# 2  11/09/2021  222.00  223.49  204.44  206.60  1,845,298
# 3  11/08/2021  212.50  225.04  212.01  218.64  2,157,912
# 4  11/05/2021  220.64  221.00  209.01  213.25  1,810,717

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume            object
# dtype: object

# %%
df.head()
# Out:
#         Date    Open    High     Low   Close     Volume
# 0 2021-11-11  200.00  208.09  198.15  204.32  1,079,401
# 1 2021-11-10  202.12  207.39  196.50  199.19  1,309,389
# 2 2021-11-09  222.00  223.49  204.44  206.60  1,845,298
# 3 2021-11-08  212.50  225.04  212.01  218.64  2,157,912
# 4 2021-11-05  220.64  221.00  209.01  213.25  1,810,717

# %%
df.set_index('Date', inplace = True)
df.head()
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2021-11-11  200.00  208.09  198.15  204.32  1,079,401
# 2021-11-10  202.12  207.39  196.50  199.19  1,309,389
# 2021-11-09  222.00  223.49  204.44  206.60  1,845,298
# 2021-11-08  212.50  225.04  212.01  218.64  2,157,912
# 2021-11-05  220.64  221.00  209.01  213.25  1,810,717

# %%
env = gym.make('stocks-v0', df = df, frame_bound = (5, 100), window_size = 5)#window_size = sonraki 5 değeri arar   frame_bound = 5 den başlayıp 100 e gidicek

# %%
env.prices
# Out:
# array([204.32, 199.19, 206.6 , 218.64, 213.25, 217.84, 218.33, 206.99,
#        200.09, 183.51, 182.85, 173.51, 177.84, 173.97, 169.8 , 181.71,
#        184.52, 186.79, 186.02, 183.28, 183.83, 184.06, 175.82, 178.1 ,
#        172.68, 172.12, 171.07, 172.18, 171.36, 176.91, 175.47, 175.92,
#        178.6 , 189.48, 185.16, 191.24, 190.14, 189.95, 192.2 , 204.97,
#        206.37, 204.52, 199.24, 203.4 , 190.41, 199.18, 198.8 , 199.  ,
#        202.75, 213.52, 212.97, 218.24, 209.2 , 204.95, 205.22, 199.65,
#        210.29, 164.89, 159.3 , 152.9 , 157.05, 163.55, 163.93, 162.52,
#        162.35, 158.78, 159.05, 161.13, 151.77, 153.44, 146.8 , 152.75,
#        157.65, 161.12, 164.86, 169.12, 178.54, 183.94, 180.36, 178.85,
#        185.81, 191.18, 173.49, 169.04, 166.82, 167.62, 180.06, 189.25,
#        191.23, 191.38, 190.66, 199.56, 202.83, 204.36, 214.14, 210.88,
#        213.25, 209.51, 212.31, 219.34])

# %%
#env.signal_features

# %% [markdown]
# # 2. Build Environment

# %%
state = env.reset()
while True: 
    action = env.action_space.sample()
    n_state, reward, done, info = env.step(action)
    if done: 
        print("info", info)
        break
        
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
# info {'total_reward': -51.51999999999998, 'total_profit': 0.4949757573026533, 'position': 0}

# %% [markdown]
# # 3. Build Environment and Train

# %%
df = pd.read_csv('data/Download Data - STOCK_US_XNYS_GME.csv')

# %%
env_maker = lambda: gym.make('stocks-v0', df=df, frame_bound=(5,100), window_size=5)
env = DummyVecEnv([env_maker])

# %%
model = A2C('MlpLstmPolicy', env, verbose=1) 
model.learn(total_timesteps=1000000)
# Out:
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\stable_baselines\common\policies.py:420: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\stable_baselines\a2c\a2c.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\stable_baselines\common\tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\stable_baselines\a2c\a2c.py:184: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\stable_baselines\a2c\a2c.py:194: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\tolga\Anaconda3\envs\trading\lib\site-packages\stable_baselines\a2c\a2c.py:196: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# ---------------------------------
# | explained_variance | -195     |
# | fps                | 9        |
# | nupdates           | 1        |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 5        |
# | value_loss         | 0.00198  |
# ---------------------------------
# ----------------------------------
# | explained_variance | -7.59e-05 |
# | fps                | 340       |
# | nupdates           | 100       |
# | policy_entropy     | 0.692     |
# | total_timesteps    | 500       |
# | value_loss         | 175       |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.0468   |
# | fps                | 445      |
# | nupdates           | 200      |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 1000     |
# | value_loss         | 0.591    |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000612 |
# | fps                | 497       |
# | nupdates           | 300       |
# | policy_entropy     | 0.691     |
# | total_timesteps    | 1500      |
# | value_loss         | 74.3      |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.00344 |
# | fps                | 528      |
# | nupdates           | 400      |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 2000     |
# | value_loss         | 13.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00406 |
# | fps                | 542      |
# | nupdates           | 500      |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 2500     |
# | value_loss         | 12.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.17    |
# | fps                | 557      |
# | nupdates           | 600      |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 3000     |
# | value_loss         | 5.52e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00955 |
# | fps                | 569      |
# | nupdates           | 700      |
# | policy_entropy     | 0.685    |
# | total_timesteps    | 3500     |
# | value_loss         | 0.722    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0026  |
# | fps                | 574      |
# | nupdates           | 800      |
# | policy_entropy     | 0.682    |
# | total_timesteps    | 4000     |
# | value_loss         | 2.29e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00128 |
# | fps                | 575      |
# | nupdates           | 900      |
# | policy_entropy     | 0.655    |
# | total_timesteps    | 4500     |
# | value_loss         | 100      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00613  |
# | fps                | 581      |
# | nupdates           | 1000     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 5000     |
# | value_loss         | 5.47     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.343    |
# | fps                | 585      |
# | nupdates           | 1100     |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 5500     |
# | value_loss         | 71.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00748 |
# | fps                | 585      |
# | nupdates           | 1200     |
# | policy_entropy     | 0.678    |
# | total_timesteps    | 6000     |
# | value_loss         | 12.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00377 |
# | fps                | 588      |
# | nupdates           | 1300     |
# | policy_entropy     | 0.656    |
# | total_timesteps    | 6500     |
# | value_loss         | 14.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00974 |
# | fps                | 591      |
# | nupdates           | 1400     |
# | policy_entropy     | 0.629    |
# | total_timesteps    | 7000     |
# | value_loss         | 163      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00384 |
# | fps                | 595      |
# | nupdates           | 1500     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 7500     |
# | value_loss         | 185      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00521  |
# | fps                | 594      |
# | nupdates           | 1600     |
# | policy_entropy     | 0.638    |
# | total_timesteps    | 8000     |
# | value_loss         | 13.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.344    |
# | fps                | 596      |
# | nupdates           | 1700     |
# | policy_entropy     | 0.584    |
# | total_timesteps    | 8500     |
# | value_loss         | 0.00771  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0133   |
# | fps                | 599      |
# | nupdates           | 1800     |
# | policy_entropy     | 0.649    |
# | total_timesteps    | 9000     |
# | value_loss         | 0.152    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00685  |
# | fps                | 601      |
# | nupdates           | 1900     |
# | policy_entropy     | 0.638    |
# | total_timesteps    | 9500     |
# | value_loss         | 147      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0281   |
# | fps                | 600      |
# | nupdates           | 2000     |
# | policy_entropy     | 0.565    |
# | total_timesteps    | 10000    |
# | value_loss         | 5.74     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00925 |
# | fps                | 602      |
# | nupdates           | 2100     |
# | policy_entropy     | 0.676    |
# | total_timesteps    | 10500    |
# | value_loss         | 21.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.115    |
# | fps                | 605      |
# | nupdates           | 2200     |
# | policy_entropy     | 0.646    |
# | total_timesteps    | 11000    |
# | value_loss         | 54.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -5.33    |
# | fps                | 604      |
# | nupdates           | 2300     |
# | policy_entropy     | 0.678    |
# | total_timesteps    | 11500    |
# | value_loss         | 0.0028   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0392   |
# | fps                | 605      |
# | nupdates           | 2400     |
# | policy_entropy     | 0.676    |
# | total_timesteps    | 12000    |
# | value_loss         | 3.05     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00674 |
# | fps                | 607      |
# | nupdates           | 2500     |
# | policy_entropy     | 0.653    |
# | total_timesteps    | 12500    |
# | value_loss         | 37.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.154   |
# | fps                | 608      |
# | nupdates           | 2600     |
# | policy_entropy     | 0.679    |
# | total_timesteps    | 13000    |
# | value_loss         | 313      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.057   |
# | fps                | 607      |
# | nupdates           | 2700     |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 13500    |
# | value_loss         | 1.65     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0857   |
# | fps                | 609      |
# | nupdates           | 2800     |
# | policy_entropy     | 0.664    |
# | total_timesteps    | 14000    |
# | value_loss         | 1.52     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.8     |
# | fps                | 611      |
# | nupdates           | 2900     |
# | policy_entropy     | 0.552    |
# | total_timesteps    | 14500    |
# | value_loss         | 0.00909  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00517 |
# | fps                | 612      |
# | nupdates           | 3000     |
# | policy_entropy     | 0.625    |
# | total_timesteps    | 15000    |
# | value_loss         | 45.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00478  |
# | fps                | 611      |
# | nupdates           | 3100     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 15500    |
# | value_loss         | 91.9     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0188  |
# | fps                | 612      |
# | nupdates           | 3200     |
# | policy_entropy     | 0.668    |
# | total_timesteps    | 16000    |
# | value_loss         | 3.01     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0069   |
# | fps                | 613      |
# | nupdates           | 3300     |
# | policy_entropy     | 0.648    |
# | total_timesteps    | 16500    |
# | value_loss         | 101      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0154  |
# | fps                | 614      |
# | nupdates           | 3400     |
# | policy_entropy     | 0.611    |
# | total_timesteps    | 17000    |
# | value_loss         | 5.88     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0304   |
# | fps                | 614      |
# | nupdates           | 3500     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 17500    |
# | value_loss         | 4.99     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00309 |
# | fps                | 613      |
# | nupdates           | 3600     |
# | policy_entropy     | 0.636    |
# | total_timesteps    | 18000    |
# | value_loss         | 147      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00308 |
# | fps                | 610      |
# | nupdates           | 3700     |
# | policy_entropy     | 0.683    |
# | total_timesteps    | 18500    |
# | value_loss         | 0.000196 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00321  |
# | fps                | 609      |
# | nupdates           | 3800     |
# | policy_entropy     | 0.648    |
# | total_timesteps    | 19000    |
# | value_loss         | 3.91     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00196 |
# | fps                | 609      |
# | nupdates           | 3900     |
# | policy_entropy     | 0.673    |
# | total_timesteps    | 19500    |
# | value_loss         | 0.433    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.461    |
# | fps                | 610      |
# | nupdates           | 4000     |
# | policy_entropy     | 0.638    |
# | total_timesteps    | 20000    |
# | value_loss         | 4.89e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00292  |
# | fps                | 611      |
# | nupdates           | 4100     |
# | policy_entropy     | 0.616    |
# | total_timesteps    | 20500    |
# | value_loss         | 54.9     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0015   |
# | fps                | 610      |
# | nupdates           | 4200     |
# | policy_entropy     | 0.649    |
# | total_timesteps    | 21000    |
# | value_loss         | 43.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0183   |
# | fps                | 611      |
# | nupdates           | 4300     |
# | policy_entropy     | 0.673    |
# | total_timesteps    | 21500    |
# | value_loss         | 41.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0571   |
# | fps                | 612      |
# | nupdates           | 4400     |
# | policy_entropy     | 0.646    |
# | total_timesteps    | 22000    |
# | value_loss         | 186      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00397  |
# | fps                | 612      |
# | nupdates           | 4500     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 22500    |
# | value_loss         | 280      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.51     |
# | fps                | 612      |
# | nupdates           | 4600     |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 23000    |
# | value_loss         | 31.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | nan      |
# | fps                | 613      |
# | nupdates           | 4700     |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 23500    |
# | value_loss         | 9.76     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.143    |
# | fps                | 613      |
# | nupdates           | 4800     |
# | policy_entropy     | 0.649    |
# | total_timesteps    | 24000    |
# | value_loss         | 0.0208   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0185  |
# | fps                | 613      |
# | nupdates           | 4900     |
# | policy_entropy     | 0.683    |
# | total_timesteps    | 24500    |
# | value_loss         | 3.42     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0013  |
# | fps                | 614      |
# | nupdates           | 5000     |
# | policy_entropy     | 0.66     |
# | total_timesteps    | 25000    |
# | value_loss         | 147      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00904 |
# | fps                | 614      |
# | nupdates           | 5100     |
# | policy_entropy     | 0.633    |
# | total_timesteps    | 25500    |
# | value_loss         | 2.2      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00123 |
# | fps                | 615      |
# | nupdates           | 5200     |
# | policy_entropy     | 0.669    |
# | total_timesteps    | 26000    |
# | value_loss         | 1.04e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00025  |
# | fps                | 615      |
# | nupdates           | 5300     |
# | policy_entropy     | 0.671    |
# | total_timesteps    | 26500    |
# | value_loss         | 16.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.34    |
# | fps                | 616      |
# | nupdates           | 5400     |
# | policy_entropy     | 0.574    |
# | total_timesteps    | 27000    |
# | value_loss         | 0.00573  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00376 |
# | fps                | 617      |
# | nupdates           | 5500     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 27500    |
# | value_loss         | 89.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00369 |
# | fps                | 617      |
# | nupdates           | 5600     |
# | policy_entropy     | 0.666    |
# | total_timesteps    | 28000    |
# | value_loss         | 392      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00603  |
# | fps                | 617      |
# | nupdates           | 5700     |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 28500    |
# | value_loss         | 51.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.191    |
# | fps                | 617      |
# | nupdates           | 5800     |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 29000    |
# | value_loss         | 172      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00498 |
# | fps                | 618      |
# | nupdates           | 5900     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 29500    |
# | value_loss         | 87.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.65    |
# | fps                | 618      |
# | nupdates           | 6000     |
# | policy_entropy     | 0.679    |
# | total_timesteps    | 30000    |
# | value_loss         | 0.0119   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00776  |
# | fps                | 619      |
# | nupdates           | 6100     |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 30500    |
# | value_loss         | 60.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00363 |
# | fps                | 619      |
# | nupdates           | 6200     |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 31000    |
# | value_loss         | 59.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0157   |
# | fps                | 619      |
# | nupdates           | 6300     |
# | policy_entropy     | 0.68     |
# | total_timesteps    | 31500    |
# | value_loss         | 17.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00955  |
# | fps                | 620      |
# | nupdates           | 6400     |
# | policy_entropy     | 0.677    |
# | total_timesteps    | 32000    |
# | value_loss         | 11.9     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0222  |
# | fps                | 620      |
# | nupdates           | 6500     |
# | policy_entropy     | 0.649    |
# | total_timesteps    | 32500    |
# | value_loss         | 9.22     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.107    |
# | fps                | 620      |
# | nupdates           | 6600     |
# | policy_entropy     | 0.662    |
# | total_timesteps    | 33000    |
# | value_loss         | 147      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00522 |
# | fps                | 621      |
# | nupdates           | 6700     |
# | policy_entropy     | 0.677    |
# | total_timesteps    | 33500    |
# | value_loss         | 94.6     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00635  |
# | fps                | 621      |
# | nupdates           | 6800     |
# | policy_entropy     | 0.679    |
# | total_timesteps    | 34000    |
# | value_loss         | 36.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.11    |
# | fps                | 621      |
# | nupdates           | 6900     |
# | policy_entropy     | 0.655    |
# | total_timesteps    | 34500    |
# | value_loss         | 16.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.604    |
# | fps                | 622      |
# | nupdates           | 7000     |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 35000    |
# | value_loss         | 0.0106   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.019    |
# | fps                | 622      |
# | nupdates           | 7100     |
# | policy_entropy     | 0.586    |
# | total_timesteps    | 35500    |
# | value_loss         | 0.454    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0239   |
# | fps                | 622      |
# | nupdates           | 7200     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 36000    |
# | value_loss         | 6.62     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0713   |
# | fps                | 622      |
# | nupdates           | 7300     |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 36500    |
# | value_loss         | 0.707    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0182   |
# | fps                | 623      |
# | nupdates           | 7400     |
# | policy_entropy     | 0.586    |
# | total_timesteps    | 37000    |
# | value_loss         | 16.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00935 |
# | fps                | 623      |
# | nupdates           | 7500     |
# | policy_entropy     | 0.679    |
# | total_timesteps    | 37500    |
# | value_loss         | 46.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00441 |
# | fps                | 623      |
# | nupdates           | 7600     |
# | policy_entropy     | 0.484    |
# | total_timesteps    | 38000    |
# | value_loss         | 20       |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00684  |
# | fps                | 623      |
# | nupdates           | 7700     |
# | policy_entropy     | 0.63     |
# | total_timesteps    | 38500    |
# | value_loss         | 43.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00573  |
# | fps                | 622      |
# | nupdates           | 7800     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 39000    |
# | value_loss         | 90.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.75    |
# | fps                | 622      |
# | nupdates           | 7900     |
# | policy_entropy     | 0.612    |
# | total_timesteps    | 39500    |
# | value_loss         | 0.0131   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00927 |
# | fps                | 621      |
# | nupdates           | 8000     |
# | policy_entropy     | 0.58     |
# | total_timesteps    | 40000    |
# | value_loss         | 11.2     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000199 |
# | fps                | 622       |
# | nupdates           | 8100      |
# | policy_entropy     | 0.481     |
# | total_timesteps    | 40500     |
# | value_loss         | 124       |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.0166   |
# | fps                | 622      |
# | nupdates           | 8200     |
# | policy_entropy     | 0.656    |
# | total_timesteps    | 41000    |
# | value_loss         | 7.04     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0243   |
# | fps                | 622      |
# | nupdates           | 8300     |
# | policy_entropy     | 0.611    |
# | total_timesteps    | 41500    |
# | value_loss         | 5.24     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0102   |
# | fps                | 621      |
# | nupdates           | 8400     |
# | policy_entropy     | 0.685    |
# | total_timesteps    | 42000    |
# | value_loss         | 36.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.102   |
# | fps                | 621      |
# | nupdates           | 8500     |
# | policy_entropy     | 0.65     |
# | total_timesteps    | 42500    |
# | value_loss         | 6.12     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0249   |
# | fps                | 620      |
# | nupdates           | 8600     |
# | policy_entropy     | 0.633    |
# | total_timesteps    | 43000    |
# | value_loss         | 34.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00618  |
# | fps                | 619      |
# | nupdates           | 8700     |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 43500    |
# | value_loss         | 254      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.072    |
# | fps                | 619      |
# | nupdates           | 8800     |
# | policy_entropy     | 0.672    |
# | total_timesteps    | 44000    |
# | value_loss         | 47.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.128   |
# | fps                | 618      |
# | nupdates           | 8900     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 44500    |
# | value_loss         | 0.645    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00802 |
# | fps                | 619      |
# | nupdates           | 9000     |
# | policy_entropy     | 0.683    |
# | total_timesteps    | 45000    |
# | value_loss         | 25.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.13     |
# | fps                | 618      |
# | nupdates           | 9100     |
# | policy_entropy     | 0.618    |
# | total_timesteps    | 45500    |
# | value_loss         | 885      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00272 |
# | fps                | 619      |
# | nupdates           | 9200     |
# | policy_entropy     | 0.598    |
# | total_timesteps    | 46000    |
# | value_loss         | 31.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00167 |
# | fps                | 619      |
# | nupdates           | 9300     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 46500    |
# | value_loss         | 5.09     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0372  |
# | fps                | 619      |
# | nupdates           | 9400     |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 47000    |
# | value_loss         | 6.04     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.015    |
# | fps                | 619      |
# | nupdates           | 9500     |
# | policy_entropy     | 0.679    |
# | total_timesteps    | 47500    |
# | value_loss         | 10.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00908 |
# | fps                | 619      |
# | nupdates           | 9600     |
# | policy_entropy     | 0.652    |
# | total_timesteps    | 48000    |
# | value_loss         | 12       |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00576 |
# | fps                | 619      |
# | nupdates           | 9700     |
# | policy_entropy     | 0.66     |
# | total_timesteps    | 48500    |
# | value_loss         | 12.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0141  |
# | fps                | 619      |
# | nupdates           | 9800     |
# | policy_entropy     | 0.66     |
# | total_timesteps    | 49000    |
# | value_loss         | 1.58     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000835 |
# | fps                | 619       |
# | nupdates           | 9900      |
# | policy_entropy     | 0.682     |
# | total_timesteps    | 49500     |
# | value_loss         | 2.23e+03  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.00237  |
# | fps                | 619      |
# | nupdates           | 10000    |
# | policy_entropy     | 0.68     |
# | total_timesteps    | 50000    |
# | value_loss         | 230      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0724  |
# | fps                | 620      |
# | nupdates           | 10100    |
# | policy_entropy     | 0.667    |
# | total_timesteps    | 50500    |
# | value_loss         | 1.22     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000337 |
# | fps                | 619       |
# | nupdates           | 10200     |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 51000     |
# | value_loss         | 20.1      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.0368   |
# | fps                | 619      |
# | nupdates           | 10300    |
# | policy_entropy     | 0.631    |
# | total_timesteps    | 51500    |
# | value_loss         | 68.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0564   |
# | fps                | 620      |
# | nupdates           | 10400    |
# | policy_entropy     | 0.677    |
# | total_timesteps    | 52000    |
# | value_loss         | 2.65     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.387   |
# | fps                | 620      |
# | nupdates           | 10500    |
# | policy_entropy     | 0.619    |
# | total_timesteps    | 52500    |
# | value_loss         | 0.0552   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0137   |
# | fps                | 620      |
# | nupdates           | 10600    |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 53000    |
# | value_loss         | 12.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00234 |
# | fps                | 620      |
# | nupdates           | 10700    |
# | policy_entropy     | 0.656    |
# | total_timesteps    | 53500    |
# | value_loss         | 7.92     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.134   |
# | fps                | 620      |
# | nupdates           | 10800    |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 54000    |
# | value_loss         | 105      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.32    |
# | fps                | 620      |
# | nupdates           | 10900    |
# | policy_entropy     | 0.573    |
# | total_timesteps    | 54500    |
# | value_loss         | 0.0179   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -14.2    |
# | fps                | 620      |
# | nupdates           | 11000    |
# | policy_entropy     | 0.46     |
# | total_timesteps    | 55000    |
# | value_loss         | 0.00767  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00619 |
# | fps                | 620      |
# | nupdates           | 11100    |
# | policy_entropy     | 0.559    |
# | total_timesteps    | 55500    |
# | value_loss         | 9.74     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.872    |
# | fps                | 619      |
# | nupdates           | 11200    |
# | policy_entropy     | 0.533    |
# | total_timesteps    | 56000    |
# | value_loss         | 0.000566 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.07     |
# | fps                | 618      |
# | nupdates           | 11300    |
# | policy_entropy     | 0.664    |
# | total_timesteps    | 56500    |
# | value_loss         | 214      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0044  |
# | fps                | 618      |
# | nupdates           | 11400    |
# | policy_entropy     | 0.689    |
# | total_timesteps    | 57000    |
# | value_loss         | 154      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0177  |
# | fps                | 618      |
# | nupdates           | 11500    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 57500    |
# | value_loss         | 36.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.81    |
# | fps                | 619      |
# | nupdates           | 11600    |
# | policy_entropy     | 0.375    |
# | total_timesteps    | 58000    |
# | value_loss         | 0.192    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.454   |
# | fps                | 618      |
# | nupdates           | 11700    |
# | policy_entropy     | 0.27     |
# | total_timesteps    | 58500    |
# | value_loss         | 0.000305 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0096  |
# | fps                | 618      |
# | nupdates           | 11800    |
# | policy_entropy     | 0.645    |
# | total_timesteps    | 59000    |
# | value_loss         | 3.25     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00803 |
# | fps                | 618      |
# | nupdates           | 11900    |
# | policy_entropy     | 0.667    |
# | total_timesteps    | 59500    |
# | value_loss         | 60       |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0233  |
# | fps                | 618      |
# | nupdates           | 12000    |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 60000    |
# | value_loss         | 16.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2.09    |
# | fps                | 618      |
# | nupdates           | 12100    |
# | policy_entropy     | 0.675    |
# | total_timesteps    | 60500    |
# | value_loss         | 2.5      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.115    |
# | fps                | 618      |
# | nupdates           | 12200    |
# | policy_entropy     | 0.651    |
# | total_timesteps    | 61000    |
# | value_loss         | 0.0173   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0684  |
# | fps                | 619      |
# | nupdates           | 12300    |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 61500    |
# | value_loss         | 0.619    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0127   |
# | fps                | 619      |
# | nupdates           | 12400    |
# | policy_entropy     | 0.683    |
# | total_timesteps    | 62000    |
# | value_loss         | 9.3      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0442   |
# | fps                | 619      |
# | nupdates           | 12500    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 62500    |
# | value_loss         | 2.45     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00141 |
# | fps                | 619      |
# | nupdates           | 12600    |
# | policy_entropy     | 0.657    |
# | total_timesteps    | 63000    |
# | value_loss         | 26.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0157  |
# | fps                | 619      |
# | nupdates           | 12700    |
# | policy_entropy     | 0.639    |
# | total_timesteps    | 63500    |
# | value_loss         | 5.25     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00163  |
# | fps                | 619      |
# | nupdates           | 12800    |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 64000    |
# | value_loss         | 36       |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0136  |
# | fps                | 619      |
# | nupdates           | 12900    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 64500    |
# | value_loss         | 3.14     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0266  |
# | fps                | 620      |
# | nupdates           | 13000    |
# | policy_entropy     | 0.681    |
# | total_timesteps    | 65000    |
# | value_loss         | 3.91     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0136   |
# | fps                | 620      |
# | nupdates           | 13100    |
# | policy_entropy     | 0.685    |
# | total_timesteps    | 65500    |
# | value_loss         | 16.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00352 |
# | fps                | 620      |
# | nupdates           | 13200    |
# | policy_entropy     | 0.664    |
# | total_timesteps    | 66000    |
# | value_loss         | 15       |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00418 |
# | fps                | 620      |
# | nupdates           | 13300    |
# | policy_entropy     | 0.644    |
# | total_timesteps    | 66500    |
# | value_loss         | 35.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0263  |
# | fps                | 620      |
# | nupdates           | 13400    |
# | policy_entropy     | 0.669    |
# | total_timesteps    | 67000    |
# | value_loss         | 63       |
# ---------------------------------
# ---------------------------------
# | explained_variance | -20.2    |
# | fps                | 620      |
# | nupdates           | 13500    |
# | policy_entropy     | 0.627    |
# | total_timesteps    | 67500    |
# | value_loss         | 86.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.079   |
# | fps                | 620      |
# | nupdates           | 13600    |
# | policy_entropy     | 0.676    |
# | total_timesteps    | 68000    |
# | value_loss         | 20.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00598 |
# | fps                | 620      |
# | nupdates           | 13700    |
# | policy_entropy     | 0.677    |
# | total_timesteps    | 68500    |
# | value_loss         | 25.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.302    |
# | fps                | 620      |
# | nupdates           | 13800    |
# | policy_entropy     | 0.668    |
# | total_timesteps    | 69000    |
# | value_loss         | 355      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00284  |
# | fps                | 619      |
# | nupdates           | 13900    |
# | policy_entropy     | 0.668    |
# | total_timesteps    | 69500    |
# | value_loss         | 202      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00317  |
# | fps                | 619      |
# | nupdates           | 14000    |
# | policy_entropy     | 0.686    |
# | total_timesteps    | 70000    |
# | value_loss         | 8.32     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0768   |
# | fps                | 620      |
# | nupdates           | 14100    |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 70500    |
# | value_loss         | 40.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.981   |
# | fps                | 620      |
# | nupdates           | 14200    |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 71000    |
# | value_loss         | 0.0407   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0541   |
# | fps                | 620      |
# | nupdates           | 14300    |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 71500    |
# | value_loss         | 7.78     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00451 |
# | fps                | 620      |
# | nupdates           | 14400    |
# | policy_entropy     | 0.662    |
# | total_timesteps    | 72000    |
# | value_loss         | 21.9     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0052   |
# | fps                | 620      |
# | nupdates           | 14500    |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 72500    |
# | value_loss         | 17.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.787   |
# | fps                | 620      |
# | nupdates           | 14600    |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 73000    |
# | value_loss         | 15.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.546   |
# | fps                | 620      |
# | nupdates           | 14700    |
# | policy_entropy     | 0.665    |
# | total_timesteps    | 73500    |
# | value_loss         | 0.023    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.013    |
# | fps                | 620      |
# | nupdates           | 14800    |
# | policy_entropy     | 0.667    |
# | total_timesteps    | 74000    |
# | value_loss         | 0.668    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00786 |
# | fps                | 620      |
# | nupdates           | 14900    |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 74500    |
# | value_loss         | 32.6     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00256 |
# | fps                | 619      |
# | nupdates           | 15000    |
# | policy_entropy     | 0.652    |
# | total_timesteps    | 75000    |
# | value_loss         | 17       |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.000818 |
# | fps                | 619      |
# | nupdates           | 15100    |
# | policy_entropy     | 0.686    |
# | total_timesteps    | 75500    |
# | value_loss         | 46.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00279  |
# | fps                | 619      |
# | nupdates           | 15200    |
# | policy_entropy     | 0.639    |
# | total_timesteps    | 76000    |
# | value_loss         | 39.6     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00243  |
# | fps                | 620      |
# | nupdates           | 15300    |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 76500    |
# | value_loss         | 82.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0411   |
# | fps                | 619      |
# | nupdates           | 15400    |
# | policy_entropy     | 0.648    |
# | total_timesteps    | 77000    |
# | value_loss         | 2.73     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0235  |
# | fps                | 619      |
# | nupdates           | 15500    |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 77500    |
# | value_loss         | 185      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -615     |
# | fps                | 620      |
# | nupdates           | 15600    |
# | policy_entropy     | 0.564    |
# | total_timesteps    | 78000    |
# | value_loss         | 2.18     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0121   |
# | fps                | 620      |
# | nupdates           | 15700    |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 78500    |
# | value_loss         | 397      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.275    |
# | fps                | 620      |
# | nupdates           | 15800    |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 79000    |
# | value_loss         | 0.596    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.24    |
# | fps                | 620      |
# | nupdates           | 15900    |
# | policy_entropy     | 0.521    |
# | total_timesteps    | 79500    |
# | value_loss         | 17.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0186   |
# | fps                | 620      |
# | nupdates           | 16000    |
# | policy_entropy     | 0.536    |
# | total_timesteps    | 80000    |
# | value_loss         | 420      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0193  |
# | fps                | 620      |
# | nupdates           | 16100    |
# | policy_entropy     | 0.658    |
# ...
# | fps                | 578      |
# | nupdates           | 194200   |
# | policy_entropy     | 0.69     |
# | total_timesteps    | 971000   |
# | value_loss         | 10.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0386   |
# | fps                | 578      |
# | nupdates           | 194300   |
# | policy_entropy     | 0.686    |
# | total_timesteps    | 971500   |
# | value_loss         | 80.9     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.012    |
# | fps                | 578      |
# | nupdates           | 194400   |
# | policy_entropy     | 0.672    |
# | total_timesteps    | 972000   |
# | value_loss         | 11.6     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00498 |
# | fps                | 577      |
# | nupdates           | 194500   |
# | policy_entropy     | 0.571    |
# | total_timesteps    | 972500   |
# | value_loss         | 44.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.306    |
# | fps                | 577      |
# | nupdates           | 194600   |
# | policy_entropy     | 0.49     |
# | total_timesteps    | 973000   |
# | value_loss         | 0.149    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0354  |
# | fps                | 577      |
# | nupdates           | 194700   |
# | policy_entropy     | 0.409    |
# | total_timesteps    | 973500   |
# | value_loss         | 347      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00905  |
# | fps                | 577      |
# | nupdates           | 194800   |
# | policy_entropy     | 0.41     |
# | total_timesteps    | 974000   |
# | value_loss         | 161      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.222    |
# | fps                | 577      |
# | nupdates           | 194900   |
# | policy_entropy     | 0.347    |
# | total_timesteps    | 974500   |
# | value_loss         | 294      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.171    |
# | fps                | 577      |
# | nupdates           | 195000   |
# | policy_entropy     | 0.322    |
# | total_timesteps    | 975000   |
# | value_loss         | 16.9     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.44    |
# | fps                | 577      |
# | nupdates           | 195100   |
# | policy_entropy     | 0.253    |
# | total_timesteps    | 975500   |
# | value_loss         | 0.147    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0087   |
# | fps                | 577      |
# | nupdates           | 195200   |
# | policy_entropy     | 0.487    |
# | total_timesteps    | 976000   |
# | value_loss         | 21.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.313    |
# | fps                | 577      |
# | nupdates           | 195300   |
# | policy_entropy     | 0.0358   |
# | total_timesteps    | 976500   |
# | value_loss         | 0.000836 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -517     |
# | fps                | 577      |
# | nupdates           | 195400   |
# | policy_entropy     | 0.052    |
# | total_timesteps    | 977000   |
# | value_loss         | 0.0147   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.218   |
# | fps                | 577      |
# | nupdates           | 195500   |
# | policy_entropy     | 0.0348   |
# | total_timesteps    | 977500   |
# | value_loss         | 0.000244 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -3.48    |
# | fps                | 577      |
# | nupdates           | 195600   |
# | policy_entropy     | 0.034    |
# | total_timesteps    | 978000   |
# | value_loss         | 0.000869 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -228     |
# | fps                | 577      |
# | nupdates           | 195700   |
# | policy_entropy     | 0.0346   |
# | total_timesteps    | 978500   |
# | value_loss         | 0.0152   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.471   |
# | fps                | 577      |
# | nupdates           | 195800   |
# | policy_entropy     | 0.0516   |
# | total_timesteps    | 979000   |
# | value_loss         | 8.13e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -2       |
# | fps                | 577      |
# | nupdates           | 195900   |
# | policy_entropy     | 0.086    |
# | total_timesteps    | 979500   |
# | value_loss         | 0.000114 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -23.8    |
# | fps                | 577      |
# | nupdates           | 196000   |
# | policy_entropy     | 0.0752   |
# | total_timesteps    | 980000   |
# | value_loss         | 4.28e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -20.1    |
# | fps                | 577      |
# | nupdates           | 196100   |
# | policy_entropy     | 0.124    |
# | total_timesteps    | 980500   |
# | value_loss         | 0.000883 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 577      |
# | nupdates           | 196200   |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 981000   |
# | value_loss         | 0.00012  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 577      |
# | nupdates           | 196300   |
# | policy_entropy     | 0.163    |
# | total_timesteps    | 981500   |
# | value_loss         | 1.47e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.98     |
# | fps                | 577      |
# | nupdates           | 196400   |
# | policy_entropy     | 0.181    |
# | total_timesteps    | 982000   |
# | value_loss         | 3.72e-07 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -10.5    |
# | fps                | 577      |
# | nupdates           | 196500   |
# | policy_entropy     | 0.156    |
# | total_timesteps    | 982500   |
# | value_loss         | 0.00124  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -16.2    |
# | fps                | 577      |
# | nupdates           | 196600   |
# | policy_entropy     | 0.131    |
# | total_timesteps    | 983000   |
# | value_loss         | 0.000248 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.393    |
# | fps                | 577      |
# | nupdates           | 196700   |
# | policy_entropy     | 0.249    |
# | total_timesteps    | 983500   |
# | value_loss         | 0.000214 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00517  |
# | fps                | 577      |
# | nupdates           | 196800   |
# | policy_entropy     | 0.67     |
# | total_timesteps    | 984000   |
# | value_loss         | 110      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00105 |
# | fps                | 577      |
# | nupdates           | 196900   |
# | policy_entropy     | 0.605    |
# | total_timesteps    | 984500   |
# | value_loss         | 121      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.888    |
# | fps                | 577      |
# | nupdates           | 197000   |
# | policy_entropy     | 0.577    |
# | total_timesteps    | 985000   |
# | value_loss         | 2.05     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.46    |
# | fps                | 577      |
# | nupdates           | 197100   |
# | policy_entropy     | 0.616    |
# | total_timesteps    | 985500   |
# | value_loss         | 1.36     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00142 |
# | fps                | 576      |
# | nupdates           | 197200   |
# | policy_entropy     | 0.646    |
# | total_timesteps    | 986000   |
# | value_loss         | 336      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -4.3     |
# | fps                | 576      |
# | nupdates           | 197300   |
# | policy_entropy     | 0.685    |
# | total_timesteps    | 986500   |
# | value_loss         | 0.00315  |
# ---------------------------------
# ---------------------------------
# | explained_variance | nan      |
# | fps                | 576      |
# | nupdates           | 197400   |
# | policy_entropy     | 0.313    |
# | total_timesteps    | 987000   |
# | value_loss         | 1.6      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -16      |
# | fps                | 576      |
# | nupdates           | 197500   |
# | policy_entropy     | 0.138    |
# | total_timesteps    | 987500   |
# | value_loss         | 0.000174 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -98.3    |
# | fps                | 576      |
# | nupdates           | 197600   |
# | policy_entropy     | 0.472    |
# | total_timesteps    | 988000   |
# | value_loss         | 0.0987   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.013   |
# | fps                | 576      |
# | nupdates           | 197700   |
# | policy_entropy     | 0.688    |
# | total_timesteps    | 988500   |
# | value_loss         | 4.06     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.476   |
# | fps                | 576      |
# | nupdates           | 197800   |
# | policy_entropy     | 0.671    |
# | total_timesteps    | 989000   |
# | value_loss         | 0.0148   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.121   |
# | fps                | 576      |
# | nupdates           | 197900   |
# | policy_entropy     | 0.585    |
# | total_timesteps    | 989500   |
# | value_loss         | 8.55     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0265  |
# | fps                | 576      |
# | nupdates           | 198000   |
# | policy_entropy     | 0.678    |
# | total_timesteps    | 990000   |
# | value_loss         | 106      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.108    |
# | fps                | 576      |
# | nupdates           | 198100   |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 990500   |
# | value_loss         | 8.25     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00378  |
# | fps                | 576      |
# | nupdates           | 198200   |
# | policy_entropy     | 0.685    |
# | total_timesteps    | 991000   |
# | value_loss         | 213      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.027   |
# | fps                | 576      |
# | nupdates           | 198300   |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 991500   |
# | value_loss         | 2.76     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.965   |
# | fps                | 576      |
# | nupdates           | 198400   |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 992000   |
# | value_loss         | 0.0993   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00314 |
# | fps                | 576      |
# | nupdates           | 198500   |
# | policy_entropy     | 0.691    |
# | total_timesteps    | 992500   |
# | value_loss         | 38.7     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000883 |
# | fps                | 576       |
# | nupdates           | 198600    |
# | policy_entropy     | 0.648     |
# | total_timesteps    | 993000    |
# | value_loss         | 236       |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.0139  |
# | fps                | 576      |
# | nupdates           | 198700   |
# | policy_entropy     | 0.635    |
# | total_timesteps    | 993500   |
# | value_loss         | 43.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.175    |
# | fps                | 576      |
# | nupdates           | 198800   |
# | policy_entropy     | 0.665    |
# | total_timesteps    | 994000   |
# | value_loss         | 0.00445  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00687 |
# | fps                | 576      |
# | nupdates           | 198900   |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 994500   |
# | value_loss         | 18.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0602   |
# | fps                | 576      |
# | nupdates           | 199000   |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 995000   |
# | value_loss         | 10.9     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00956 |
# | fps                | 576      |
# | nupdates           | 199100   |
# | policy_entropy     | 0.685    |
# | total_timesteps    | 995500   |
# | value_loss         | 18.6     |
# ---------------------------------
# ----------------------------------
# | explained_variance | -0.000746 |
# | fps                | 576       |
# | nupdates           | 199200    |
# | policy_entropy     | 0.693     |
# | total_timesteps    | 996000    |
# | value_loss         | 6.48      |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.201    |
# | fps                | 576      |
# | nupdates           | 199300   |
# | policy_entropy     | 0.661    |
# | total_timesteps    | 996500   |
# | value_loss         | 18.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00788 |
# | fps                | 576      |
# | nupdates           | 199400   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 997000   |
# | value_loss         | 226      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.01     |
# | fps                | 576      |
# | nupdates           | 199500   |
# | policy_entropy     | 0.683    |
# | total_timesteps    | 997500   |
# | value_loss         | 17.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.81    |
# | fps                | 576      |
# | nupdates           | 199600   |
# | policy_entropy     | 0.547    |
# | total_timesteps    | 998000   |
# | value_loss         | 24.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0169  |
# | fps                | 575      |
# | nupdates           | 199700   |
# | policy_entropy     | 0.683    |
# | total_timesteps    | 998500   |
# | value_loss         | 16.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0722   |
# | fps                | 575      |
# | nupdates           | 199800   |
# | policy_entropy     | 0.693    |
# | total_timesteps    | 999000   |
# | value_loss         | 3.41     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.599    |
# | fps                | 575      |
# | nupdates           | 199900   |
# | policy_entropy     | 0.687    |
# | total_timesteps    | 999500   |
# | value_loss         | 14.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.539    |
# | fps                | 575      |
# | nupdates           | 200000   |
# | policy_entropy     | 0.692    |
# | total_timesteps    | 1000000  |
# | value_loss         | 0.00464  |
# ---------------------------------

# %%
save_path = os.path.join('Training','Saved Models')
A2C_trading = os.path.join(save_path, 'A2C_trading')

model.save(A2C_trading)

# %%
frame_bound=(90,110)
date_list = df['Date'].tolist()[frame_bound[0]-5:frame_bound[1]]

env = gym.make('stocks-v0', df=df, frame_bound=frame_bound, window_size=5)

obs = env.reset()
while True: 
    obs = obs[np.newaxis, ...]
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    if done: 
        print("info", info)
        break
        
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
# info {'total_reward': 0.7299999999999613, 'total_profit': 0.9638218597761822, 'position': 0}

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize = (16,10));
fig.suptitle('Vertically stacked subplots');
fig.subplots_adjust(bottom=0.02)
env.render_all();

#date 
ax1.plot(date_list, env.prices);
ax1.tick_params(axis = 'x', labelrotation=45)

# %%
df[df['Date'] == '06/09/2021']
# Out:
#            Date    Open   High     Low   Close      Volume
# 109  06/09/2021  303.12  328.0  291.51  302.56  13,429,310

# %% [markdown]
# ## TradingEnv'i genişletin ve değiştirin
# Verileri işlemek ve ortam dışından özellikler çıkarmak istemeniz durumunda, bunu iki yöntemle kolayca yapabilirsiniz:

# %%
def my_process_data(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'Low'].to_numpy()[start:end]
    signal_features = env.df.loc[:, ['Close', 'Open', 'High', 'Low']].to_numpy()[start:end]
    return prices, signal_features


class MyForexEnv(ForexEnv):
    _process_data = my_process_data


my_env = MyForexEnv(df=FOREX_EURUSD_1H_ASK, window_size=12, frame_bound=(12, len(FOREX_EURUSD_1H_ASK)))

# %%
my_env.prices
# Out:
# array([1.05221, 1.05226, 1.05268, ..., 1.20073, 1.19978, 1.19931])

# %%
my_env.signal_features
# Out:
# array([[1.05227, 1.05236, 1.05253, 1.05221],
#        [1.05282, 1.05227, 1.05426, 1.05226],
#        [1.05281, 1.05283, 1.05283, 1.05268],
#        ...,
#        [1.20096, 1.20139, 1.20144, 1.20073],
#        [1.19982, 1.20098, 1.20109, 1.19978],
#        [1.20075, 1.19984, 1.2013 , 1.19931]])
