# %%
from scipy.stats import binom

# %%
p = 0.01
n = 100
bn = binom(n,p)
print(bn.pmf(1))
print(bn.pmf(5))
print(bn.pmf(10))
# Out:
# 0.36972963764971983
# 0.0028977871237616114
# 7.006035693977161e-08
