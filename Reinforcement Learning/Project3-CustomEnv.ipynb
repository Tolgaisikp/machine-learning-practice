# %% [markdown]
# # 1. Import Dependencies

# %%
import gym 
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 
import numpy as np
import random
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2.Types of Spaces

# %%
Discrete(3)
# Out:
# Discrete(3)

# %%
Discrete(3).sample()#0 3 arası değer verir
# Out:
# 0

# %%
Box(0,1,shape=(3,3))
# Out:
# Box(3, 3)

# %%
Box(0,1,shape=(3,3)).sample()
# Out:
# array([[0.43941042, 0.40097845, 0.91754013],
#        [0.57950145, 0.42512247, 0.9853515 ],
#        [0.91749656, 0.79901713, 0.27786884]], dtype=float32)

# %%
Tuple((Discrete(3), Box(0,1,shape=(3,3))))
# Out:
# Tuple(Discrete(3), Box(3, 3))

# %%
Tuple((Discrete(3), Box(0,1,shape=(3,3)))).sample()
# Out:
# (1,
#  array([[0.47558898, 0.3124085 , 0.22419007],
#         [0.4304858 , 0.57674485, 0.1130814 ],
#         [0.65798616, 0.6950891 , 0.1922135 ]], dtype=float32))

# %%
Dict({'height':Discrete(3), 'speed':Box(0,1,shape=(3,3))})
# Out:
# Dict(height:Discrete(3), speed:Box(3, 3))

# %%
Dict({'height':Discrete(3), 'speed':Box(0,100,shape=(1,))}).sample()
# Out:
# OrderedDict([('height', 0), ('speed', array([40.954315], dtype=float32))])

# %%
MultiBinary(4)
# Out:
# MultiBinary(4)

# %%
MultiBinary(4).sample()
# Out:
# array([1, 0, 1, 0], dtype=int8)

# %%
MultiDiscrete([5,6,3])
# Out:
# MultiDiscrete([5 6 3])

# %%
MultiDiscrete([5,6,3]).sample()
# Out:
# array([1, 5, 1], dtype=int64)

# %%
for i in range(10):
    print(Discrete(3).sample()-1)
# Out:
# -1
# -1
# 0
# -1
# 1
# -1
# -1
# -1
# -1
# 0

# %% [markdown]
# # 3. Building an Environment
# - Build an agent to give us the best shower possible
# - Randomly temperature
# - 37 and 39 degrees optimum temperature

# %%
class ShowerEnv(Env):
    def __init__(self):
        self.action_space = Discrete(3)
        self.observation_space = Box(low = np.array([0]), high = np.array([100]))
        self.state = 38 + random.randint(-3,3)
        self.shower_length = 60
        
    def step(self, action):
        #apply temperature adjust
        self.state += action-1# 0=> -1 temperature decrease 1=> 0 nothing happens 2=> 1 temperature increase  
        
        #decrease shower time
        self.shower_length -= 1
        
        #calculate reward
        if self.state >= 37 and self.state <= 39:
            reward = +1
        else:
            reward = -1
            
        if self.shower_length <= 0:
            done = True
        else:
            done = False
        
        info = {}
        
        return self.state, reward, done, info
    
    def render(self):
        #implement viz
        pass
    
    def reset(self):
        self.state = np.array([38 + random.randint(-3, 3)]).astype(float)
        self.shower_length = 60
        return self.state

# %%
shower = ShowerEnv()

# %% [markdown]
# # 4. Test Environment

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = shower.reset()
    done = False
    score = 0 
    
    while not done:
        shower.render()
        action = shower.action_space.sample()
        obs, reward, done, info = shower.step(action)
        #print(obs, action-1, reward, done, info)
        score+=reward
        
    print('Episode:{} Score:{}'.format(episode, score))
shower.close()
# Out:
# Episode:1 Score:-6
# Episode:2 Score:-10
# Episode:3 Score:8
# Episode:4 Score:-16
# Episode:5 Score:-60

# %% [markdown]
# # 5. Train Model

# %%
log_path = os.path.join('Training', 'Logs')
model = PPO('MlpPolicy', shower, verbose = 1, tensorboard_log = log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=500000)
# Out:
# Logging to Training\Logs\PPO_6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -24.8    |
# | time/              |          |
# |    fps             | 318      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -32.9       |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011065196 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000335   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.3        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.005      |
# |    value_loss           | 49.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -33.3       |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008521572 |
# |    clip_fraction        | 0.0415      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.000859    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00163    |
# |    value_loss           | 43.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -36.7       |
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 4           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006960258 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 3.35e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.000828   |
# |    value_loss           | 57.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -29.4        |
# | time/                   |              |
# |    fps                  | 304          |
# |    iterations           | 5            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0063554537 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -1.23e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.9         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 64.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -27.7        |
# | time/                   |              |
# |    fps                  | 295          |
# |    iterations           | 6            |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0012143084 |
# |    clip_fraction        | 0.0085       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -5.25e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.8         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000252    |
# |    value_loss           | 77           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25.3       |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 7           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011022065 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 3.31e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0018     |
# |    value_loss           | 73.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25.2       |
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 8           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009268935 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.000154    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.1        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00471    |
# |    value_loss           | 82.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -26.4        |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 9            |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0070651295 |
# |    clip_fraction        | 0.0616       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.000936    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.3         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 66.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25.4       |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 10          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008494262 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.000998    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.6        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00469    |
# |    value_loss           | 70.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25.2       |
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 11          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011400306 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.00495    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.6        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00922    |
# |    value_loss           | 75.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -25.5        |
# | time/                   |              |
# |    fps                  | 277          |
# |    iterations           | 12           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0054998593 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -1.86e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.7         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00259     |
# |    value_loss           | 78.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -24.5        |
# | time/                   |              |
# |    fps                  | 277          |
# |    iterations           | 13           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0059549115 |
# |    clip_fraction        | 0.0653       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.00164     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.4         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00483     |
# |    value_loss           | 68.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -27.5        |
# | time/                   |              |
# |    fps                  | 273          |
# |    iterations           | 14           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0020376258 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.00139      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.9         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 76.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -26.9       |
# | time/                   |             |
# |    fps                  | 271         |
# |    iterations           | 15          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008833503 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.00634     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.9        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00644    |
# |    value_loss           | 67.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -27.3        |
# | time/                   |              |
# |    fps                  | 272          |
# |    iterations           | 16           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0057890313 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.00218     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.9         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00369     |
# |    value_loss           | 84.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -24.2       |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 17          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008836168 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.000643    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44          |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00284    |
# |    value_loss           | 79.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -16.2       |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 18          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.013956188 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.00875     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.1        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 78.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -13         |
# | time/                   |             |
# |    fps                  | 266         |
# |    iterations           | 19          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007606031 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.00138     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.3        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00469    |
# |    value_loss           | 71.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -11.6      |
# | time/                   |            |
# |    fps                  | 263        |
# |    iterations           | 20         |
# |    time_elapsed         | 155        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00977247 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.996     |
# |    explained_variance   | -0.0232    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 37.1       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0134    |
# |    value_loss           | 66.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -11.3      |
# | time/                   |            |
# |    fps                  | 265        |
# |    iterations           | 21         |
# |    time_elapsed         | 161        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00655228 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.98      |
# |    explained_variance   | 0.000596   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.4       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00922   |
# |    value_loss           | 60.4       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -9.3         |
# | time/                   |              |
# |    fps                  | 267          |
# |    iterations           | 22           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0054057944 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.965       |
# |    explained_variance   | -0.0105      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.8         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 71.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -7.36        |
# | time/                   |              |
# |    fps                  | 270          |
# |    iterations           | 23           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0049617398 |
# |    clip_fraction        | 0.0701       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.973       |
# |    explained_variance   | 9.75e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.7         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00441     |
# |    value_loss           | 63.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -7.16        |
# | time/                   |              |
# |    fps                  | 271          |
# |    iterations           | 24           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0053797667 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.974       |
# |    explained_variance   | -0.0127      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28           |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 65.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -5.26       |
# | time/                   |             |
# |    fps                  | 273         |
# |    iterations           | 25          |
# |    time_elapsed         | 187         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009063115 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.973      |
# |    explained_variance   | 0.0106      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.6        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 60.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -3.3        |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 26          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005010745 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.934      |
# |    explained_variance   | 0.0381      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.5        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00363    |
# |    value_loss           | 55.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -2.8         |
# | time/                   |              |
# |    fps                  | 275          |
# |    iterations           | 27           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0015033792 |
# |    clip_fraction        | 0.0533       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.924       |
# |    explained_variance   | 0.0237       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28           |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 0.000571     |
# |    value_loss           | 59.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 3.38        |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 28          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008144742 |
# |    clip_fraction        | 0.0591      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | -0.0475     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.1        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00374    |
# |    value_loss           | 55.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 11.5         |
# | time/                   |              |
# |    fps                  | 269          |
# |    iterations           | 29           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0072209025 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.898       |
# |    explained_variance   | 0.00197      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.8         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.0014       |
# |    value_loss           | 46.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 30          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009370641 |
# |    clip_fraction        | 0.092       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.86       |
# |    explained_variance   | 0.00506     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.6        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 41.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 17          |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 31          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.004400361 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.827      |
# |    explained_variance   | 0.0257      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.1        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00824    |
# |    value_loss           | 62.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 15.4        |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 32          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.003944599 |
# |    clip_fraction        | 0.0934      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.794      |
# |    explained_variance   | 0.0239      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.9        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00185     |
# |    value_loss           | 49.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 16.5        |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 33          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.012504669 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.794      |
# |    explained_variance   | -0.0887     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00477    |
# |    value_loss           | 58.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 20.2        |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 34          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009157394 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.794      |
# |    explained_variance   | 0.000396    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.2        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.000515   |
# |    value_loss           | 63          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 25.9         |
# | time/                   |              |
# |    fps                  | 269          |
# |    iterations           | 35           |
# |    time_elapsed         | 266          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0047561205 |
# |    clip_fraction        | 0.0948       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.811       |
# |    explained_variance   | 0.000142     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.9         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00164     |
# |    value_loss           | 43.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 31.3        |
# | time/                   |             |
# |    fps                  | 268         |
# |    iterations           | 36          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008973911 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.79       |
# |    explained_variance   | -0.0013     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.9        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 58.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 34.3        |
# | time/                   |             |
# |    fps                  | 269         |
# |    iterations           | 37          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011652229 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.797      |
# |    explained_variance   | -0.000162   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.9        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00224    |
# |    value_loss           | 57.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 36.8        |
# | time/                   |             |
# |    fps                  | 270         |
# |    iterations           | 38          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011007141 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.803      |
# |    explained_variance   | 0.000197    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.1        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00041     |
# |    value_loss           | 50.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 40.2        |
# | time/                   |             |
# |    fps                  | 271         |
# |    iterations           | 39          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008881828 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.806      |
# |    explained_variance   | 0.000242    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.9        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.000647   |
# |    value_loss           | 70.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.4        |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 40          |
# |    time_elapsed         | 301         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006805111 |
# |    clip_fraction        | 0.0926      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | -4.08e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.3        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.000582    |
# |    value_loss           | 67.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 46.3       |
# | time/                   |            |
# |    fps                  | 272        |
# |    iterations           | 41         |
# |    time_elapsed         | 308        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.01042587 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.807     |
# |    explained_variance   | -5.92e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 28.2       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.00378    |
# |    value_loss           | 68.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.5        |
# | time/                   |             |
# |    fps                  | 273         |
# |    iterations           | 42          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006359145 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.821      |
# |    explained_variance   | -1.73e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.4        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00516     |
# |    value_loss           | 79.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.1        |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 43          |
# |    time_elapsed         | 321         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.007865487 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.842      |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.7        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00583     |
# |    value_loss           | 81.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 46.2        |
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 44          |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.013692962 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | -1.91e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.4        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00717     |
# |    value_loss           | 86.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.1        |
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 45          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008336588 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | -2.35e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.9        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00219     |
# |    value_loss           | 90.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.5        |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 46          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008700679 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.82       |
# |    explained_variance   | -7.99e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.7        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00938     |
# |    value_loss           | 81.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.6        |
# | time/                   |             |
# |    fps                  | 277         |
# |    iterations           | 47          |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.015970271 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.818      |
# |    explained_variance   | 2.22e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39          |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00797     |
# |    value_loss           | 88.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 49.9         |
# | time/                   |              |
# |    fps                  | 276          |
# |    iterations           | 48           |
# |    time_elapsed         | 354          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0070996084 |
# |    clip_fraction        | 0.183        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.805       |
# |    explained_variance   | 1.14e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.2         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.00868      |
# |    value_loss           | 87.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.8        |
# | time/                   |             |
# |    fps                  | 278         |
# |    iterations           | 49          |
# |    time_elapsed         | 360         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.010094066 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.5        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00919     |
# |    value_loss           | 88.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.4        |
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 50          |
# |    time_elapsed         | 365         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.013128086 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 7.15e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44          |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00957     |
# |    value_loss           | 97.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.5        |
# | time/                   |             |
# |    fps                  | 281         |
# |    iterations           | 51          |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.009724455 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.823      |
# |    explained_variance   | 5.84e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.3        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00875     |
# |    value_loss           | 99.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 46.7        |
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 52          |
# |    time_elapsed         | 375         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.011703547 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.83       |
# |    explained_variance   | -6.44e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.7        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.00375     |
# |    value_loss           | 103         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.5        |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 53          |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.008420649 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.814      |
# |    explained_variance   | -1.13e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40          |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00651    |
# |    value_loss           | 98.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.7        |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 54          |
# |    time_elapsed         | 386         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.013111053 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | -2.53e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.4        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.0078      |
# |    value_loss           | 87.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 47.8         |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 55           |
# |    time_elapsed         | 391          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0075890273 |
# |    clip_fraction        | 0.161        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.813       |
# |    explained_variance   | -9.54e-07    |
# ...
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.7        |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 228         |
# |    time_elapsed         | 1550        |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.010275906 |
# |    clip_fraction        | 0.0463      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.166      |
# |    explained_variance   | -0.00162    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.8        |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | 0.00807     |
# |    value_loss           | 107         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.1        |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 229         |
# |    time_elapsed         | 1555        |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.004441497 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.155      |
# |    explained_variance   | -0.0132     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.9        |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | 0.0037      |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.1        |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 230         |
# |    time_elapsed         | 1560        |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.040537983 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.2        |
# |    explained_variance   | 0.00373     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.5        |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.00275    |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.8        |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 231         |
# |    time_elapsed         | 1566        |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.014096343 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.203      |
# |    explained_variance   | -0.00974    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44          |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | 0.00775     |
# |    value_loss           | 105         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 45.8         |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 232          |
# |    time_elapsed         | 1573         |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0102475695 |
# |    clip_fraction        | 0.0781       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.191       |
# |    explained_variance   | -0.00638     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.2         |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | 0.0169       |
# |    value_loss           | 128          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 44.8          |
# | time/                   |               |
# |    fps                  | 301           |
# |    iterations           | 233           |
# |    time_elapsed         | 1581          |
# |    total_timesteps      | 477184        |
# | train/                  |               |
# |    approx_kl            | 0.00046884976 |
# |    clip_fraction        | 0.0534        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.173        |
# |    explained_variance   | 0.0353        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 54.4          |
# |    n_updates            | 2320          |
# |    policy_gradient_loss | 0.00254       |
# |    value_loss           | 112           |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | 47.9      |
# | time/                   |           |
# |    fps                  | 301       |
# |    iterations           | 234       |
# |    time_elapsed         | 1590      |
# |    total_timesteps      | 479232    |
# | train/                  |           |
# |    approx_kl            | 0.1385203 |
# |    clip_fraction        | 0.117     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.228    |
# |    explained_variance   | 0.0826    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 54.9      |
# |    n_updates            | 2330      |
# |    policy_gradient_loss | -0.00818  |
# |    value_loss           | 110       |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 53.4         |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 235          |
# |    time_elapsed         | 1598         |
# |    total_timesteps      | 481280       |
# | train/                  |              |
# |    approx_kl            | 0.0041473294 |
# |    clip_fraction        | 0.0713       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.19        |
# |    explained_variance   | -0.0516      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45           |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | 0.0142       |
# |    value_loss           | 94.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 52.9        |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 236         |
# |    time_elapsed         | 1608        |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.029415188 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.176      |
# |    explained_variance   | -0.000867   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.2        |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | 0.0192      |
# |    value_loss           | 103         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.7        |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 237         |
# |    time_elapsed         | 1617        |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.017524023 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.159      |
# |    explained_variance   | 0.00243     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.2        |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | 0.000189    |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.7        |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 238         |
# |    time_elapsed         | 1626        |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.008522842 |
# |    clip_fraction        | 0.0635      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.206      |
# |    explained_variance   | -0.0296     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.5        |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | 0.00144     |
# |    value_loss           | 139         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 45.2         |
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 239          |
# |    time_elapsed         | 1635         |
# |    total_timesteps      | 489472       |
# | train/                  |              |
# |    approx_kl            | 0.0032392228 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.17        |
# |    explained_variance   | -0.0016      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.7         |
# |    n_updates            | 2380         |
# |    policy_gradient_loss | 0.0123       |
# |    value_loss           | 95.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.8        |
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 240         |
# |    time_elapsed         | 1645        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.004087799 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.206      |
# |    explained_variance   | -0.00233    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.2        |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | 0.00207     |
# |    value_loss           | 118         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 49.3       |
# | time/                   |            |
# |    fps                  | 298        |
# |    iterations           | 241        |
# |    time_elapsed         | 1654       |
# |    total_timesteps      | 493568     |
# | train/                  |            |
# |    approx_kl            | 0.06833722 |
# |    clip_fraction        | 0.0521     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.211     |
# |    explained_variance   | 0.000286   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49.8       |
# |    n_updates            | 2400       |
# |    policy_gradient_loss | 0.00431    |
# |    value_loss           | 101        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.6        |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 242         |
# |    time_elapsed         | 1663        |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.066288546 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.23       |
# |    explained_variance   | -0.0174     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.3        |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | 0.0146      |
# |    value_loss           | 109         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.3        |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 243         |
# |    time_elapsed         | 1672        |
# |    total_timesteps      | 497664      |
# | train/                  |             |
# |    approx_kl            | 0.011000274 |
# |    clip_fraction        | 0.0498      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.181      |
# |    explained_variance   | -0.00596    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.6        |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | 0.00608     |
# |    value_loss           | 103         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 48.1         |
# | time/                   |              |
# |    fps                  | 297          |
# |    iterations           | 244          |
# |    time_elapsed         | 1681         |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0074297613 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.168       |
# |    explained_variance   | 0.00448      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61.4         |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | 0.00536      |
# |    value_loss           | 105          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 48.7       |
# | time/                   |            |
# |    fps                  | 297        |
# |    iterations           | 245        |
# |    time_elapsed         | 1688       |
# |    total_timesteps      | 501760     |
# | train/                  |            |
# |    approx_kl            | 0.08088687 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.197     |
# |    explained_variance   | 0.023      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 51.8       |
# |    n_updates            | 2440       |
# |    policy_gradient_loss | -0.00394   |
# |    value_loss           | 124        |
# ----------------------------------------

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = shower.reset()
    done = False
    score = 0 
    
    while not done:
        shower.render()
        action, _ = model.predict(obs)
        obs, reward, done, info = shower.step(action)
        #print(obs, action-1, reward, done, info)
        score+=reward
        
    print('Episode:{} Score:{}'.format(episode, score))
shower.close()
# Out:
# Episode:1 Score:60
# Episode:2 Score:58
# Episode:3 Score:58
# Episode:4 Score:54
# Episode:5 Score:56

# %% [markdown]
# # 6 Save Model

# %%
save_path = os.path.join('Training', 'Saved Models','Shower_Model_PPO')
model.save(save_path)

# %%
evaluate_policy(model, shower, n_eval_episodes = 10)
# Out:
# (12.0, 58.787753826796276)
